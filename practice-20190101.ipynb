# %%
import requests
from os import path
    
def init_image():
    imgName = 'res\image.jpg'
    if not path.isfile(imgName):
        res = requests.get('https://blog.gtwang.org/wp-content/uploads/2018/03/human-20180303-01-1024x683.jpg')
        with open(imgName, 'wb') as f:
            f.write(res.content)
    return imgName

# %%
# pip3 install pillow
from PIL import Image
Image.open(init_image())
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x587A908>

# %%
import numpy as np
import cv2

# 讀取圖檔
img = cv2.imread(init_image())

# 讓視窗可以自由縮放大小
cv2.namedWindow('My Image', cv2.WINDOW_NORMAL)

# 顯示圖片
cv2.imshow('My Image', img)

# 按下任意鍵則關閉所有視窗
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# 將 BGR 圖片轉為 RGB 圖片
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 使用 Matplotlib 顯示圖片
plt.imshow(img_rgb)
plt.show()

# %%
# (height, width, channel)
# channel: 3=RGB, 1=灰階
img.shape
# Out:
# (683, 1024, 3)
