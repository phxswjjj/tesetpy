# %%
import utility.config as cfg
gamename = cfg.readFirstLine('game')

# %%
from inst.win32 import wnd

w = wnd()
w.load(gamename)

# %%
w.grab()
w.image
# Out:
# <PIL.Image.Image image mode=RGB size=1606x925 at 0x4EE56D8>

# %%
from pymouse import PyMouse
from pykeyboard import PyKeyboard
import time

def click(w, rx, ry):
    w.focus()
    w.click_l(rx, ry)

def tap(w, c):
    w.focus()
    w.tap(c)
    
click(w, 55, 870)
time.sleep(1.5)
click(w, 55, 870)
time.sleep(1.5)
tap(w, 'n')
time.sleep(1.5)
tap(w, 'b')
